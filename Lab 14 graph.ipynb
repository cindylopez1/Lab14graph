# %%
# import packages
import statistics
import pandas as pd
import scipy.stats as stats
from scipy.stats import sem
from statistics import mean, stdev
import matplotlib.pyplot as plt
import numpy as np
#include if using a jupyter notebook, remove if using a .py file
# %matplotlib inline

# %%
f_vc=[2.7,3.7,3.2,3.45,3.2,3.1]
m_vc=[3.3,4.5,3.7]

# %%
fvc_mean=mean(f_vc)
mvc_mean=mean(m_vc)
fvc_mean, mvc_mean
# Out:
# (3.225, 3.8333333333333335)

# %%
fvc_sem=sem(f_vc)
mvc_sem=sem(m_vc)
fvc_sem, mvc_sem
# Out:
# (0.13768926368215256, 0.3527668414752788)

# %%
# build a bar plot
plt.bar(['Female VC','Male VC'],[fvc_mean,mvc_mean],yerr=[fvc_sem,mvc_sem],capsize=10)
plt.xlabel('Biological Sex')
plt.ylabel('Vital Capacity (L)')
plt.title('Vital Capacity Differences in Female vs Male')
# Out:
# Text(0.5, 1.0, 'Vital Capacity Differences in Female vs Male')

# %%
ffev1=[2.37,3.37,2.6,2.69,3.13,2.44]
mfev1=[3.3,4.86,3.7]

# %%
ffev1_mean=mean(ffev1)
mfev1_mean=mean(mfev1)
ffev1_mean, mfev1_mean
# Out:
# (2.7666666666666666, 3.9533333333333336)

# %%
ffev1_sem=sem(ffev1)
mfev1_sem=sem(mfev1)
ffev1_sem, mfev1_sem
# Out:
# (0.16265846973882972, 0.4678081278093024)

# %%
plt.bar(['Female FEV1','Male FEV1'],[ffev1_mean,mfev1_mean],yerr=[ffev1_sem,mfev1_sem],capsize=10)
plt.xlabel('Biological Sex')
plt.ylabel('FEV1')
plt.title('FEV1 Differences in Female vs Male')
# Out:
# Text(0.5, 1.0, 'FEV1 Differences in Female vs Male')
